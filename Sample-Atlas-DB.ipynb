# %%
# set up on Atlas first
# https://allenai.org/data/cord-19
#

# %%
#!pip install pymongo
#!pip install pymongo[srv]
#!pip install dnspython

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
# note - this URL may not work, as I may take it off line when the workshop is not in session
# you'll need to set up a username and password for your MongoDB and add them to the URL below. 
MDB_URL = "mongodb+srv://python_workshop_user:python_workshop_pwd@python-mongodb-workshop-unmjr.gcp.mongodb.net/test"

# %%
client = MongoClient(MDB_URL)

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
db = client.get_database("sample_restaurants")

# %%
db.list_collection_names()
# Out:
# ['restaurants', 'neighborhoods']

# %%
restaurants = db.get_collection("restaurants")

# %%
restaurants
# Out:
# Collection(Database(MongoClient(host=['python-mongodb-workshop-shard-00-00-unmjr.gcp.mongodb.net:27017', 'python-mongodb-workshop-shard-00-01-unmjr.gcp.mongodb.net:27017', 'python-mongodb-workshop-shard-00-02-unmjr.gcp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Python-MongoDB-Workshop-shard-0', ssl=True), 'sample_restaurants'), 'restaurants')

# %%
for r in restaurants.find_one():
    print(r)
# Out:
# _id
# address
# borough
# cuisine
# grades
# name
# restaurant_id

# %%
for r in restaurants.find({'cuisine': 'Irish'}):
    print(r)
# Out:
# {'_id': ObjectId('5eb3d668b31de5d588f42939'), 'address': {'building': '351', 'coord': [-73.98513559999999, 40.7676919], 'street': 'West   57 Street', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'Irish', 'grades': [{'date': datetime.datetime(2014, 9, 6, 0, 0), 'grade': 'A', 'score': 2}, {'date': datetime.datetime(2013, 7, 22, 0, 0), 'grade': 'A', 'score': 11}, {'date': datetime.datetime(2012, 7, 31, 0, 0), 'grade': 'A', 'score': 12}, {'date': datetime.datetime(2011, 12, 29, 0, 0), 'grade': 'A', 'score': 12}], 'name': 'Dj Reynolds Pub And Restaurant', 'restaurant_id': '30191841'}
# ...

# %%
for r in restaurants.find({'cuisine': 'Irish'}, {'_id':0, 'borough': 1}):
    print(r['borough'])
# Out:
# Manhattan
# Bronx
# Manhattan
# Manhattan
# Queens
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Queens
# Manhattan
# Queens
# Bronx
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Queens
# Manhattan
# Manhattan
# Manhattan
# Brooklyn
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Queens
# Queens
# Manhattan
# Queens
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Brooklyn
# Queens
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Queens
# Bronx
# Manhattan
# Manhattan
# Queens
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Bronx
# Queens
# Queens
# Manhattan
# Brooklyn
# Manhattan
# Queens
# Manhattan
# Manhattan
# Manhattan
# Queens
# Bronx
# Manhattan
# Manhattan
# Queens
# Manhattan
# Brooklyn
# Manhattan
# Manhattan
# Manhattan
# Bronx
# Manhattan
# Bronx
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Manhattan
# Queens
# Manhattan
# Queens
# Manhattan
# ...

# %%
for r in restaurants.find({ '$or' : [ { 'cuisine' : 'Irish' }, { 'cuisine' : 'Indian' } ] }):
    print(r['name'], r['borough'], r['cuisine'])
# Out:
# Dj Reynolds Pub And Restaurant Manhattan Irish
# Mcdwyers Pub Bronx Irish
# Twins Pub Manhattan Irish
# Blarney Rock Manhattan Irish
# O'Hanlon'S Pub Queens Irish
# Dorrian'S Red Hand Restaurant Manhattan Irish
# Blarney Stone Manhattan Irish
# Mcsorley'S Old Ale House Manhattan Irish
# Moran'S Chelsea Manhattan Irish
# Irish Cottage Queens Irish
# Killarney Rose Manhattan Irish
# Rogers Irish Tavern Queens Irish
# Aqueduct North Bronx Irish
# Molly Wee Pub Manhattan Irish
# Annam Braham Restaurant Queens Indian
# Pj Carney'S Manhattan Irish
# Mcaleer'S Pub Manhattan Irish
# Agra Restaurant Manhattan Indian
# Gandhi Manhattan Indian
# Mughlai Restaurant Manhattan Indian
# Jim Brady'S Restaurant Manhattan Irish
# Rosie O'Grady Restaurant Manhattan Irish
# Ready Penny Inn Queens Irish
# India Passage Restaurant Brooklyn Indian
# Malachy'S Manhattan Irish
# The Beekman Manhattan Irish
# Taste Of India Ii Restaurant Staten Island Indian
# Irish Brigade Manhattan Irish
# ...

# %%
for r in restaurants.find({'name': 'Rogers Irish Tavern' } ):
    print(r['borough'], r['cuisine'])
# Out:
# Queens Irish

# %%
for r in restaurants.find({'cuisine': { '$in': [ "Irish", "Indian" ] } }, 
                          {'name': 1, 'cuisine': 1, 'borough': 1, '_id': 0}):
    print(r['borough'], r['cuisine'])
# Out:
# Manhattan Irish
# Bronx Irish
# Manhattan Irish
# Manhattan Irish
# Queens Irish
# Manhattan Irish
# Manhattan Irish
# Manhattan Irish
# Manhattan Irish
# Queens Irish
# Manhattan Irish
# Queens Irish
# Bronx Irish
# Manhattan Irish
# Queens Indian
# Manhattan Irish
# Manhattan Irish
# Manhattan Indian
# Manhattan Indian
# Manhattan Indian
# Manhattan Irish
# Manhattan Irish
# Queens Irish
# Brooklyn Indian
# Manhattan Irish
# Manhattan Irish
# Staten Island Indian
# Manhattan Irish
# Brooklyn Irish
# Manhattan Indian
# Manhattan Irish
# Manhattan Irish
# Manhattan Irish
# Manhattan Irish
# Manhattan Irish
# Queens Irish
# Manhattan Indian
# Manhattan Indian
# Queens Irish
# Manhattan Irish
# Queens Irish
# Manhattan Irish
# Manhattan Irish
# Manhattan Irish
# Manhattan Indian
# Manhattan Indian
# Manhattan Indian
# Manhattan Irish
# Manhattan Indian
# Queens Indian
# Queens Indian
# Manhattan Irish
# Manhattan Irish
# Manhattan Indian
# Manhattan Irish
# Manhattan Irish
# ...

# %%
db.restaurants.distinct("cuisine")
# Out:
# ['Afghan',
#  'African',
#  'American',
#  'Armenian',
#  'Asian',
#  'Australian',
#  'Bagels/Pretzels',
#  'Bakery',
#  'Bangladeshi',
#  'Barbecue',
#  'Bottled beverages, including water, sodas, juices, etc.',
#  'Brazilian',
#  'CafÃ©/Coffee/Tea',
#  'Café/Coffee/Tea',
#  'Cajun',
#  'Californian',
#  'Caribbean',
#  'Chicken',
#  'Chilean',
#  'Chinese',
#  'Chinese/Cuban',
#  'Chinese/Japanese',
#  'Continental',
#  'Creole',
#  'Creole/Cajun',
#  'Czech',
#  'Delicatessen',
#  'Donuts',
#  'Eastern European',
#  'Egyptian',
#  'English',
#  'Ethiopian',
#  'Filipino',
#  'French',
#  'Fruits/Vegetables',
#  'German',
#  'Greek',
#  'Hamburgers',
#  'Hawaiian',
#  'Hotdogs',
#  'Hotdogs/Pretzels',
#  'Ice Cream, Gelato, Yogurt, Ices',
#  'Indian',
#  'Indonesian',
#  'Iranian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Jewish/Kosher',
#  'Juice, Smoothies, Fruit Salads',
#  'Korean',
#  'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'Mediterranean',
# ...

# %%
#for r in restaurants.find({'name': 'Rogers Irish Tavern' } ):
#    print(r['borough'], r['cuisine'])

for agg in db.restaurants.aggregate([{'$group':{'_id':'$cuisine','count':{'$sum': 1}}}]):
    print(agg)
# Out:
# {'_id': 'Filipino', 'count': 26}
# {'_id': 'Southwestern', 'count': 9}
# {'_id': 'Pizza', 'count': 1163}
# {'_id': 'Jewish/Kosher', 'count': 316}
# {'_id': 'Salads', 'count': 45}
# {'_id': 'English', 'count': 16}
# {'_id': 'Pakistani', 'count': 31}
# {'_id': 'Steak', 'count': 86}
# {'_id': 'Peruvian', 'count': 68}
# {'_id': 'Bangladeshi', 'count': 36}
# {'_id': 'Italian', 'count': 1069}
# {'_id': 'Barbecue', 'count': 52}
# {'_id': 'Afghan', 'count': 14}
# {'_id': 'Vietnamese/Cambodian/Malaysia', 'count': 66}
# {'_id': 'Scandinavian', 'count': 7}
# {'_id': 'Cajun', 'count': 7}
# {'_id': 'Continental', 'count': 58}
# {'_id': 'Bagels/Pretzels', 'count': 168}
# {'_id': 'Soups & Sandwiches', 'count': 51}
# {'_id': 'Hamburgers', 'count': 433}
# {'_id': 'Seafood', 'count': 147}
# {'_id': 'Mediterranean', 'count': 219}
# {'_id': 'Chinese/Japanese', 'count': 59}
# {'_id': 'Portuguese', 'count': 8}
# {'_id': 'Turkish', 'count': 70}
# {'_id': 'Not Listed/Not Applicable', 'count': 19}
# ...

# %%
import re
regx = re.compile("^deli", re.IGNORECASE)
for r in restaurants.find({'name': { '$regex': regx } }):
    print(r['name'])
# Out:
# Deli Plus ( Inside Port Authority Station)
# Delight Donut
# Delias Lounge Cafe
# Delizia  Ristorante
# Delicias Cuencanas Bar-Restaurant Deli,
# Deli Express
# Delicious Chinese
# Delicias Manabitas Restaurant
# Delicias Tropical Restaurant
# Delight 28 Restaurant
# Deli Manjoo Bakery
# Delissimo Deli & Cafe
# Delicia Dona Maria Restaurant
# Delicatessen Macbar
# Deli & Grill
# Delicioso Restaurant
# Delicias Mexicanas
# Delicia Bakery
# Delimarie
# Deli Plant Milk Store
# Delicious Bakery
# Deli & Coffee Corp. Breakfast & Lunch
# Delios Pizza
# Delicias Calenas #2
# Delizia 92
# Delicious On Lydig
# Delicious Fruits
# Deli Doroj Fried Chicken And Pizza
# Delicias Pizza And Chicken
# Delicious Juice Bar
# Delicias Bakery & Restaurant
# Delish By Amerivents
# Deli Pizza Pizzeria & Taqueria
# Deli El Bigotes
# Deli & Grocery
# Delis 48
# Delicias Ambatenas
# Delicias Colombianas Bakery
# Delilah'S Steaks
# Delicias Bakery
# Delish Kitchen
# Delicias Calenas Bakery & Restaurant
# ...

# %%
agg = db.restaurants.aggregate([{'$group':{'_id':'$cuisine','count':{'$sum': 1}}}])

# %%
for a in agg:
    print(a)
# Out:
# {'_id': 'Filipino', 'count': 26}
# {'_id': 'Southwestern', 'count': 9}
# {'_id': 'Pizza', 'count': 1163}
# {'_id': 'Jewish/Kosher', 'count': 316}
# {'_id': 'Salads', 'count': 45}
# {'_id': 'English', 'count': 16}
# {'_id': 'Pakistani', 'count': 31}
# {'_id': 'Steak', 'count': 86}
# {'_id': 'Peruvian', 'count': 68}
# {'_id': 'Bangladeshi', 'count': 36}
# {'_id': 'Italian', 'count': 1069}
# {'_id': 'Barbecue', 'count': 52}
# {'_id': 'Afghan', 'count': 14}
# {'_id': 'Vietnamese/Cambodian/Malaysia', 'count': 66}
# {'_id': 'Scandinavian', 'count': 7}
# {'_id': 'Cajun', 'count': 7}
# {'_id': 'Continental', 'count': 58}
# {'_id': 'Bagels/Pretzels', 'count': 168}
# {'_id': 'Soups & Sandwiches', 'count': 51}
# {'_id': 'Hamburgers', 'count': 433}
# {'_id': 'Seafood', 'count': 147}
# {'_id': 'Mediterranean', 'count': 219}
# {'_id': 'Chinese/Japanese', 'count': 59}
# {'_id': 'Portuguese', 'count': 8}
# {'_id': 'Turkish', 'count': 70}
# {'_id': 'Not Listed/Not Applicable', 'count': 19}
# ...

# %%
agg = db.restaurants.aggregate([{'$group':{'_id':'$cuisine','count':{'$sum': 1}}}])

# %%
for a in agg:
    print(a)
# Out:
# {'_id': 'Filipino', 'count': 26}
# {'_id': 'Southwestern', 'count': 9}
# {'_id': 'Pizza', 'count': 1163}
# {'_id': 'Jewish/Kosher', 'count': 316}
# {'_id': 'Salads', 'count': 45}
# {'_id': 'English', 'count': 16}
# {'_id': 'Pakistani', 'count': 31}
# {'_id': 'Steak', 'count': 86}
# {'_id': 'Peruvian', 'count': 68}
# {'_id': 'Bangladeshi', 'count': 36}
# {'_id': 'Italian', 'count': 1069}
# {'_id': 'Barbecue', 'count': 52}
# {'_id': 'Afghan', 'count': 14}
# {'_id': 'Vietnamese/Cambodian/Malaysia', 'count': 66}
# {'_id': 'Scandinavian', 'count': 7}
# {'_id': 'Cajun', 'count': 7}
# {'_id': 'Continental', 'count': 58}
# {'_id': 'Bagels/Pretzels', 'count': 168}
# {'_id': 'Soups & Sandwiches', 'count': 51}
# {'_id': 'Hamburgers', 'count': 433}
# {'_id': 'Seafood', 'count': 147}
# {'_id': 'Mediterranean', 'count': 219}
# {'_id': 'Chinese/Japanese', 'count': 59}
# {'_id': 'Portuguese', 'count': 8}
# {'_id': 'Turkish', 'count': 70}
# {'_id': 'Not Listed/Not Applicable', 'count': 19}
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_records(restaurants.find({'cuisine': 'Irish'}))

# %%
df
# Out:
#                           _id  \
# 0    5eb3d668b31de5d588f42939
# 1    5eb3d668b31de5d588f429bb
# 2    5eb3d668b31de5d588f429db
# 3    5eb3d668b31de5d588f429bd
# 4    5eb3d668b31de5d588f429dd
# 5    5eb3d668b31de5d588f42989
# 6    5eb3d668b31de5d588f429c4
# 7    5eb3d668b31de5d588f42987
# 8    5eb3d668b31de5d588f42992
# 9    5eb3d668b31de5d588f429c2
# 10   5eb3d668b31de5d588f429b5
# 11   5eb3d668b31de5d588f42ade
# 12   5eb3d668b31de5d588f42b0d
# 13   5eb3d668b31de5d588f42ab5
# 14   5eb3d668b31de5d588f42ae3
# 15   5eb3d668b31de5d588f42b13
# 16   5eb3d668b31de5d588f42a54
# 17   5eb3d668b31de5d588f42ab3
# 18   5eb3d668b31de5d588f42a9f
# 19   5eb3d668b31de5d588f42c37
# 20   5eb3d668b31de5d588f42c45
# 21   5eb3d668b31de5d588f42c39
# 22   5eb3d668b31de5d588f42c2b
# 23   5eb3d668b31de5d588f42b5d
# 24   5eb3d668b31de5d588f42be6
# 25   5eb3d668b31de5d588f42c71
# 26   5eb3d668b31de5d588f42ca1
# 27   5eb3d668b31de5d588f42cca
# 28   5eb3d668b31de5d588f42cae
# 29   5eb3d668b31de5d588f42c9f
# ...
